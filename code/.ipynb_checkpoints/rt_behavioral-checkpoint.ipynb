# %% [markdown]
# # Social Reward Behavioral RT Analyses

# %% [markdown]
# ## Set Up

# %%
import os
import glob
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Set paths

# %%
proj_dir = '/Users/hpopal/Google Drive/My Drive/dscn_lab/projects/scon_social_reward/'
data_dir = os.path.join(proj_dir, 'derivatives', 'task_socialreward', 'data')

os.chdir(proj_dir)

# %% [markdown]
# ### Find participants

# %%
# Import participant id data
subj_df = pd.read_csv(proj_dir+'participants.tsv', sep='\t')

# Fix participant IDs to match the directories in the data folder (e.g. sub-SCN101 -> SCN_101)
subj_df['participant_id'] = [x[4:7]+'_'+x[7:] for x in subj_df['participant_id']]

print('Found '+str(len(subj_df))+' participants')
# Out:
# Found 85 participants

# %% [markdown]
# # Data Cleaning

# %%
rt_data = pd.DataFrame(columns=['ParticipantID','Run','ConditionName',
                                'Question','QuestionNumber','First_RT',
                                'Correct_RT','valence'])

# Import data
for subj in subj_df['participant_id']:
    # Find data for all runs
    run_files = glob.glob(os.path.join(data_dir,subj,'*-errors.csv'))

    #temp_subj_df = pd.DataFrame(columns=['ParticpantID','Run','ConditionName','Correct_RT'])
    # Loop through runs and combine into one df
    for run_file in run_files:
        temp_run_data = pd.read_csv(run_file, index_col=0)
        if temp_run_data['redcap_v_task'].sum() > 0:
            continue
        else:
            temp_run_data_fltr = temp_run_data[rt_data.columns]
            rt_data = pd.concat([rt_data, temp_run_data_fltr], ignore_index=True)

# %%
# Add group info to rt data
rt_data = pd.merge(left=subj_df, right=rt_data, 
                   left_on='participant_id', right_on='ParticipantID')
rt_data = rt_data.drop('ParticipantID', axis=1)

# %%
# Create column for peer info
rt_data['Peer'] = [x.split('_')[1] for x in rt_data['ConditionName']]

# Make group data nominal
rt_data['group'] = rt_data['group'].astype(str)

rt_data
# Out:
#      participant_id group Run        ConditionName                   Question  \
# 0           SCN_101     1   2   HighReward_DisPeer        don't like baseball
# 1           SCN_101     1   2   LowReward_Computer           like phone calls
# 2           SCN_101     1   2   HighReward_SimPeer          close with family
# 3           SCN_101     1   2  HighReward_Computer       like roller coasters
# 4           SCN_101     1   2  HighReward_Computer      don't like volleyball
# ...             ...   ...  ..                  ...                        ...
# 6137        SCN_234     1   3   HighReward_DisPeer         like action movies
# 6138        SCN_234     1   3   HighReward_SimPeer                like school
# 6139        SCN_234     1   3   HighReward_SimPeer  don't like romance novels
# 6140        SCN_234     1   3   HighReward_DisPeer   don't like country music
# 6141        SCN_234     1   3    LowReward_DisPeer           don't like birds
#
#       QuestionNumber  First_RT  Correct_RT valence      Peer
# 0               92.0  0.735915    0.735915     neg   DisPeer
# 1              113.0  0.897369    0.897369     pos  Computer
# 2              164.0  1.268269    1.268269     pos   SimPeer
# 3               51.0  0.775542    0.775542     pos  Computer
# 4              110.0  1.093963    1.093963     neg  Computer
# ...              ...       ...         ...     ...       ...
# 6137            81.0  0.428082    0.428082     pos   DisPeer
# 6138            66.0  0.494318    0.494318     pos   SimPeer
# 6139            52.0  0.359078    0.359078     neg   SimPeer
# 6140           168.0  0.473353    0.473353     neg   DisPeer
# 6141           174.0  0.370476    0.370476     neg   DisPeer
#
# [6142 rows x 10 columns]

# %% [markdown]
# ## Missed Trials
#
# When a participant did not press the correct button, the feedback was "no data". This occured in two instances
# - When the participant made no button press
# - When the participant hit the incorrect button, and did not hit the correct button before the trial timed out
#
# In both these instances, the participant was not paying attention and so we should exclude these trials. If this was the case for more than 20% of the run, then we should exclude data from the entire run.

# %%
# Find participant runs with more than 20% missed trials

exclude_subj_runs = pd.DataFrame(columns=['participant_id','Run'])

subj_list = rt_data['participant_id'].unique()

for subj in subj_list:
    # Filter for subject specific data
    temp_subj_data = rt_data[rt_data['participant_id'] == subj]
    
    # Find runs per subject
    temp_runs = temp_subj_data['Run'].unique()
    
    for run in temp_runs:
        temp_run_rt = temp_subj_data.loc[temp_subj_data['Run'] == run, 'Correct_RT']
        
        # Calculate the percentage of missed trials
        temp_na_perc = np.sum(temp_run_rt.isna())/len(temp_run_rt.isna())
        
        if temp_na_perc > 0.20:
            exclude_subj_runs.loc[len(exclude_subj_runs)] = [subj,run]

# %%
exclude_subj_runs
# Out:
#   participant_id  Run
# 0        SCN_125    4
# 1        SCN_201    1

# %%
# Remove participant runs

for i in range(len(exclude_subj_runs)):
    temp_drop_idx = rt_data[(rt_data['participant_id'] == exclude_subj_runs.loc[i,'participant_id']) &
                            (rt_data['Run'] == exclude_subj_runs.loc[i,'Run'])].index
    
    rt_data = rt_data.drop(temp_drop_idx)

# %%
# Create column for missed trials
rt_data['accuracy'] = 1
rt_data.loc[rt_data['Correct_RT'].isna(), 'accuracy'] = 0

# %% [markdown]
# ## Transforming Data

# %%
# Create a copy of the data
rt_data_mod = rt_data.copy()

# Remove outliers greather than 3 SD


# Log transform
rt_data_mod['Correct_RT_log'] = np.log(rt_data_mod['Correct_RT'])

# Create empty column for log z-scored data
rt_data_mod['Correct_RT_logz'] = np.nan

for subj in rt_data_mod['participant_id']:
    # Calculate mean and SD
    temp_subj_data = rt_data_mod[rt_data_mod['participant_id'] == subj]
    temp_mean = np.mean(temp_subj_data['Correct_RT_log'])
    temp_std = np.std(temp_subj_data['Correct_RT_log'])
    
    # z-score log reaction time
    temp_logz = (rt_data_mod.loc[rt_data_mod['participant_id'] == subj,'Correct_RT_log'] - temp_mean) / temp_std
    rt_data_mod.loc[rt_data_mod['participant_id'] == subj,'Correct_RT_logz'] = temp_logz

# %%
np.std(list(temp_subj_data['Correct_RT_log']))
# Out:
# 0.2467409171800746

# %%
np.std(temp_subj_data['Correct_RT_log'])
# Out:
# 0.2467409171800746

# %%
fig, axes = plt.subplots(1, 2)
sns.histplot(data=rt_data_mod, x='Correct_RT', ax=axes[0])
sns.histplot(data=rt_data_mod, x='Correct_RT_logz', ax=axes[1])
# Out:
# <Axes: xlabel='Correct_RT_logz', ylabel='Count'>

# %% [markdown]
# ***

# %% [markdown]
# # Behavioral Analyses

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

from statsmodels.formula.api import ols

# %% [markdown]
# ## Run and Reaction Time

# %%
model_run = ols('Correct_RT_logz ~ Run', data=rt_data_mod, 
                missing='drop').fit()
print(sm.stats.anova_lm(model_run, typ=2))
# Out:
#               sum_sq      df          F        PR(>F)
# Run         67.32166     3.0  22.679787  1.351186e-14
# Residual  5939.67834  6003.0        NaN           NaN

# %%
ax = sns.boxplot(rt_data_mod, x='Run', y='Correct_RT_logz', showfliers=False)

sns.stripplot(rt_data_mod, x='Run', y='Correct_RT_logz', 
              palette='dark:black', alpha=.05, legend=False, ax=ax, jitter=True)
# Out:
# /var/folders/85/t_6qbb0j2pvbbd0sq3zrwbc00000gq/T/ipykernel_48805/3722269129.py:3: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.stripplot(rt_data_mod, x='Run', y='Correct_RT_logz',
# <Axes: xlabel='Run', ylabel='Correct_RT_logz'>

# %% [markdown]
# ## Peer Condition and Run Predicting Reaction Time

# %% [markdown]
# ### Chi-Square Test
# Contingency Table
# |          | Early Run | Late Run |
# | -------- | --------- | -------- |
# | SimPeer  |     0     |     0    |
# | DisPeer  |     0     |    0.1   |
# | Computer |     0     |    0.1   |

# %%
model_test = smf.mixedlm('Correct_RT_logz ~ 1 + Run:C(Peer) + 1', data=rt_data_mod,
                         groups=rt_data_mod['participant_id'],
                missing='drop').fit()
model_test.summary()
# Out:
# /Users/hpopal/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/hpopal/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2201: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /Users/hpopal/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:1635: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /Users/hpopal/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2238: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                 Mixed Linear Model Regression Results
# =====================================================================
# Model:                MixedLM   Dependent Variable:   Correct_RT_logz
# No. Observations:     6007      Method:               REML
# No. Groups:           78        Scale:                0.9972
# Min. group size:      22        Log-Likelihood:       -8535.4569
# Max. group size:      121       Converged:            Yes
# Mean group size:      77.0
# ---------------------------------------------------------------------
#                            Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------
# Intercept                   0.030    0.040  0.732 0.464 -0.050  0.109
# C(Peer)[T.DisPeer]          0.036    0.061  0.591 0.554 -0.084  0.156
# C(Peer)[T.SimPeer]          0.042    0.061  0.683 0.495 -0.078  0.161
# Run[T.2]:C(Peer)[Computer] -0.020    0.062 -0.325 0.745 -0.141  0.101
# Run[T.3]:C(Peer)[Computer] -0.136    0.063 -2.150 0.032 -0.260 -0.012
# Run[T.4]:C(Peer)[Computer] -0.200    0.062 -3.208 0.001 -0.322 -0.078
# Run[T.2]:C(Peer)[DisPeer]  -0.140    0.062 -2.259 0.024 -0.261 -0.019
# Run[T.3]:C(Peer)[DisPeer]  -0.230    0.063 -3.639 0.000 -0.353 -0.106
# Run[T.4]:C(Peer)[DisPeer]  -0.349    0.063 -5.580 0.000 -0.472 -0.226
# Run[T.2]:C(Peer)[SimPeer]  -0.102    0.062 -1.658 0.097 -0.223  0.019
# Run[T.3]:C(Peer)[SimPeer]  -0.220    0.063 -3.486 0.000 -0.344 -0.096
# Run[T.4]:C(Peer)[SimPeer]  -0.376    0.062 -6.063 0.000 -0.498 -0.255
# Group Var                   0.000
# =====================================================================
#
# """

# %%
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                 Mixed Linear Model Regression Results
# ======================================================================
# Model:               MixedLM    Dependent Variable:    Correct_RT_logz
# No. Observations:    6007       Method:                REML
# No. Groups:          78         Scale:                 0.9938
# Min. group size:     22         Log-Likelihood:        -8525.1163
# Max. group size:     121        Converged:             Yes
# Mean group size:     77.0
# ----------------------------------------------------------------------
#                             Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------
# Intercept                    0.052    0.042  1.248 0.212 -0.030  0.134
# Run[T.2]                    -0.020    0.062 -0.325 0.745 -0.141  0.101
# Run[T.3]                    -0.136    0.063 -2.154 0.031 -0.259 -0.012
# Run[T.4]                    -0.200    0.062 -3.213 0.001 -0.322 -0.078
# C(Peer)[T.DisPeer]           0.036    0.061  0.592 0.554 -0.083  0.155
# C(Peer)[T.SimPeer]           0.042    0.061  0.684 0.494 -0.078  0.161
# Run[T.2]:C(Peer)[T.DisPeer] -0.120    0.087 -1.374 0.170 -0.291  0.051
# Run[T.3]:C(Peer)[T.DisPeer] -0.094    0.089 -1.051 0.293 -0.269  0.081
# Run[T.4]:C(Peer)[T.DisPeer] -0.149    0.088 -1.687 0.092 -0.322  0.024
# Run[T.2]:C(Peer)[T.SimPeer] -0.082    0.087 -0.943 0.346 -0.253  0.089
# Run[T.3]:C(Peer)[T.SimPeer] -0.085    0.089 -0.947 0.344 -0.260  0.090
# Run[T.4]:C(Peer)[T.SimPeer] -0.176    0.088 -2.004 0.045 -0.349 -0.004
# Group Var                    0.000
# ======================================================================
#
# """

# %%
model_run_peer = ols('Correct_RT_logz ~ Run * C(Peer)', data=rt_data_mod, 
                missing='drop').fit()
print(sm.stats.anova_lm(model_run_peer, typ=2))
# Out:
#                   sum_sq      df          F        PR(>F)
# Run            67.295704     3.0  22.672492  1.366010e-14
# C(Peer)         3.107378     2.0   1.570353  2.080573e-01
# Run:C(Peer)     5.187398     6.0   0.873839  5.131091e-01
# Residual     5931.383564  5995.0        NaN           NaN

# %%
ax = sns.boxplot(rt_data_mod, x='Peer', y='Correct_RT_logz', hue='Run', showfliers=False)

sns.stripplot(rt_data_mod, x='Peer', y='Correct_RT_logz', hue='Run', 
              palette='dark:black', alpha=.05, legend=False, ax=ax, dodge=True)
plt.legend(bbox_to_anchor=(1.02, 1), title='Run', loc='upper left', borderaxespad=0)

# %% [markdown]
# ## Errors Per Condition
#
# Perhaps participants are missing more trials or pressing incorrect buttons for different conditions. For example, if they have learned about the dissimilar peer, maybe they feel less motivation to respond.

# %%
model_acc_peer = ols('accuracy ~ Run * C(Peer)', data=rt_data_mod, 
                missing='drop').fit()
print(sm.stats.anova_lm(model_acc_peer, typ=2))
# Out:
#                 sum_sq      df         F    PR(>F)
# Run           0.118936     3.0  2.821040  0.037438
# C(Peer)       0.016316     2.0  0.580502  0.559648
# Run:C(Peer)   0.149805     6.0  1.776621  0.099681
# Residual     85.472841  6082.0       NaN       NaN

# %%
Xtrain = rt_data_mod[['Run', 'Peer']] 
ytrain = rt_data_mod[['accuracy']] 

log_reg = sm.Logit(ytrain, Xtrain).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[171], line 4
#       1 Xtrain = rt_data_mod[['Run', 'Peer']]
#       2 ytrain = rt_data_mod[['accuracy']]
# ----> 4 log_reg = sm.Logit(ytrain, Xtrain).fit()
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:475, in BinaryModel.__init__(self, endog, exog, offset, check_rank, **kwargs)
#     472 def __init__(self, endog, exog, offset=None, check_rank=True, **kwargs):
#     473     # unconditional check, requires no extra kwargs added by subclasses
#     474     self._check_kwargs(kwargs)
# --> 475     super().__init__(endog, exog, offset=offset, check_rank=check_rank,
#     476                      **kwargs)
#     477     if not issubclass(self.__class__, MultinomialModel):
#     478         if not np.all((self.endog >= 0) & (self.endog <= 1)):
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/discrete/discrete_model.py:185, in DiscreteModel.__init__(self, endog, exog, check_rank, **kwargs)
#     183 def __init__(self, endog, exog, check_rank=True, **kwargs):
#     184     self._check_rank = check_rank
# --> 185     super().__init__(endog, exog, **kwargs)
#     186     self.raise_on_perfect_prediction = False  # keep for backwards compat
#     187     self.k_extra = 0
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:270, in LikelihoodModel.__init__(self, endog, exog, **kwargs)
#     269 def __init__(self, endog, exog=None, **kwargs):
# --> 270     super().__init__(endog, exog, **kwargs)
#     271     self.initialize()
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:95, in Model.__init__(self, endog, exog, **kwargs)
#      93 missing = kwargs.pop('missing', 'none')
#      94 hasconst = kwargs.pop('hasconst', None)
# ---> 95 self.data = self._handle_data(endog, exog, missing, hasconst,
#      96                               **kwargs)
#      97 self.k_constant = self.data.k_constant
#      98 self.exog = self.data.exog
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/model.py:135, in Model._handle_data(self, endog, exog, missing, hasconst, **kwargs)
#     134 def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 135     data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     136     # kwargs arrays could have changed, easier to just attach here
#     137     for key in kwargs:
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/data.py:675, in handle_data(endog, exog, missing, hasconst, **kwargs)
#     672     exog = np.asarray(exog)
#     674 klass = handle_data_class_factory(endog, exog)
# --> 675 return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
#     676              **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/data.py:84, in ModelData.__init__(self, endog, exog, missing, hasconst, **kwargs)
#      82     self.orig_endog = endog
#      83     self.orig_exog = exog
# ---> 84     self.endog, self.exog = self._convert_endog_exog(endog, exog)
#      86 self.const_idx = None
#      87 self.k_constant = 0
#
# File ~/anaconda3/lib/python3.11/site-packages/statsmodels/base/data.py:509, in PandasData._convert_endog_exog(self, endog, exog)
#     507 exog = exog if exog is None else np.asarray(exog)
#     508 if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 509     raise ValueError("Pandas data cast to numpy dtype of object. "
#     510                      "Check input data with np.asarray(data).")
#     511 return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
ax = sns.boxplot(rt_data_mod, x='Peer', y='accuracy', hue='Run', showfliers=False)

sns.stripplot(rt_data_mod, x='Peer', y='Correct_RT_logz', hue='Run', 
              palette='dark:black', alpha=.05, legend=False, ax=ax, dodge=True)
plt.legend(bbox_to_anchor=(1.02, 1), title='Run', loc='upper left', borderaxespad=0)

# %% [markdown]
# # Group Analyses

# %% [markdown]
# ## Non-Autistic Group

# %%
rt_data_mod_tyd = rt_data_mod[rt_data_mod['group'] == '1']
rt_data_mod_tyd
# Out:
#      participant_id group Run        ConditionName                   Question  \
# 0           SCN_101     1   2   HighReward_DisPeer        don't like baseball
# 1           SCN_101     1   2   LowReward_Computer           like phone calls
# 2           SCN_101     1   2   HighReward_SimPeer          close with family
# 3           SCN_101     1   2  HighReward_Computer       like roller coasters
# 4           SCN_101     1   2  HighReward_Computer      don't like volleyball
# ...             ...   ...  ..                  ...                        ...
# 6137        SCN_234     1   3   HighReward_DisPeer         like action movies
# 6138        SCN_234     1   3   HighReward_SimPeer                like school
# 6139        SCN_234     1   3   HighReward_SimPeer  don't like romance novels
# 6140        SCN_234     1   3   HighReward_DisPeer   don't like country music
# 6141        SCN_234     1   3    LowReward_DisPeer           don't like birds
#
#       QuestionNumber  First_RT  Correct_RT valence      Peer button_accuracy  \
# 0               92.0  0.735915    0.735915     neg   DisPeer         correct
# 1              113.0  0.897369    0.897369     pos  Computer         correct
# 2              164.0  1.268269    1.268269     pos   SimPeer         correct
# 3               51.0  0.775542    0.775542     pos  Computer         correct
# 4              110.0  1.093963    1.093963     neg  Computer         correct
# ...              ...       ...         ...     ...       ...             ...
# 6137            81.0  0.428082    0.428082     pos   DisPeer         correct
# 6138            66.0  0.494318    0.494318     pos   SimPeer         correct
# 6139            52.0  0.359078    0.359078     neg   SimPeer         correct
# 6140           168.0  0.473353    0.473353     neg   DisPeer         correct
# 6141           174.0  0.370476    0.370476     neg   DisPeer         correct
#
#       Correct_RT_log  Correct_RT_logz
# 0          -0.306641        -0.035638
# 1          -0.108288         0.647960
# 2           0.237653         1.840202
# 3          -0.254194         0.145116
# 4           0.089807         1.330670
# ...              ...              ...
# 6137       -0.848440        -0.345286
# 6138       -0.704576         0.237772
# 6139       -1.024215        -1.057670
# 6140       -0.747914         0.062130
# 6141       -0.992967        -0.931031
#
# [4055 rows x 13 columns]

# %%
model_run_peer_tyd = ols('Correct_RT_logz ~ Run * C(Peer)', data=rt_data_mod_tyd,
                        missing='drop').fit()
print(sm.stats.anova_lm(model_run_peer_tyd, typ=2))
# Out:
#                   sum_sq      df          F        PR(>F)
# Run            71.199864     3.0  24.178665  1.678647e-15
# C(Peer)         4.509709     2.0   2.297169  1.006763e-01
# Run:C(Peer)     9.661081     6.0   1.640397  1.317670e-01
# Residual     3909.632097  3983.0        NaN           NaN

# %%
ax = sns.boxplot(rt_data_mod_tyd, x='Peer', y='Correct_RT_logz', hue='Run', showfliers=False)

sns.stripplot(rt_data_mod_tyd, x='Peer', y='Correct_RT_logz', hue='Run', 
              palette='dark:black', alpha=.05, legend=False, ax=ax, dodge=True)
plt.legend(bbox_to_anchor=(1.02, 1), title='Run', loc='upper left', borderaxespad=0)

# %% [markdown]
# ## ASD Group

# %%
rt_data_mod_asd = rt_data_mod[rt_data_mod['group'] == '2']
rt_data_mod_asd
# Out:
#      participant_id group Run        ConditionName              Question  \
# 380         SCN_105     2   3   HighReward_DisPeer          like texting
# 381         SCN_105     2   3   LowReward_Computer   don't like shopping
# 382         SCN_105     2   3   HighReward_SimPeer          like museums
# 383         SCN_105     2   3  HighReward_Computer          not a reader
# 384         SCN_105     2   3  HighReward_Computer     like funny movies
# ...             ...   ...  ..                  ...                   ...
# 5847        SCN_223     2   1    LowReward_DisPeer      like sleeping in
# 5848        SCN_223     2   1   HighReward_SimPeer     don't like ballet
# 5849        SCN_223     2   1  HighReward_Computer  like to stay at home
# 5850        SCN_223     2   1    LowReward_DisPeer    don't like reading
# 5851        SCN_223     2   1   LowReward_Computer  like decorating room
#
#       QuestionNumber  First_RT  Correct_RT valence      Peer button_accuracy  \
# 380            147.0  0.428253    0.428253     pos   DisPeer         correct
# 381            206.0  1.030081    1.030081     neg  Computer         correct
# 382             84.0  0.400649    0.400649     pos   SimPeer         correct
# 383             29.0  0.338319    0.338319     neg  Computer         correct
# 384            185.0  0.780494    0.780494     pos  Computer         correct
# ...              ...       ...         ...     ...       ...             ...
# 5847           124.0  1.175249    1.175249     pos   DisPeer         correct
# 5848           191.0  0.664671    0.664671     neg   SimPeer         correct
# 5849           119.0  0.543963    0.543963     pos  Computer         correct
# 5850            10.0  1.097434    1.097434     neg   DisPeer         correct
# 5851           157.0  0.841201    0.841201     pos  Computer         correct
#
#       Correct_RT_log  Correct_RT_logz
# 380        -0.848041        -0.366011
# 381         0.029637         2.371334
# 382        -0.914670        -0.573816
# 383        -1.083767        -1.101204
# 384        -0.247828         1.505962
# ...              ...              ...
# 5847        0.161480         1.588888
# 5848       -0.408463        -0.387813
# 5849       -0.608873        -1.082883
# 5850        0.092975         1.351297
# 5851       -0.172924         0.429093
#
# [2039 rows x 13 columns]

# %%
model_run_peer_asd = ols('Correct_RT_logz ~ Run * C(Peer)', data=rt_data_mod_asd,
                        missing='drop').fit()
print(sm.stats.anova_lm(model_run_peer_asd, typ=2))
# Out:
#                   sum_sq      df         F    PR(>F)
# Run             5.702160     3.0  1.903099  0.127011
# C(Peer)         0.029036     2.0  0.014536  0.985569
# Run:C(Peer)     8.770404     6.0  1.463564  0.186877
# Residual     1997.499327  2000.0       NaN       NaN

# %%
ax = sns.boxplot(rt_data_mod_asd, x='Peer', y='Correct_RT_logz', hue='Run', showfliers=False)

sns.stripplot(rt_data_mod_asd, x='Peer', y='Correct_RT_logz', hue='Run', 
              palette='dark:black', alpha=.1, legend=False, ax=ax, dodge=True)
plt.legend(bbox_to_anchor=(1.02, 1), title='Run', loc='upper left', borderaxespad=0)

# %% [markdown]
# **Results:** In the ASD group, there was no relationship between the type of peer, run number, and log reaction times. ASD participants seem to be responding similarily throughout the task for all conditions and all runs.

# %% [markdown]
# ## TD vs ASD
# Finally, we well test for group differences.

# %%
# Create new variable to capture run and group for the hue in the bar plot
rt_data_mod['Run_group'] = rt_data_mod['Run'].astype('str') + '_' + rt_data_mod['group'].astype('str')

# %%
sns.color_palette('tab10', 4)
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392)]

# %%
sns.color_palette('pastel', 4)
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019)]

# %%
palette_a = sns.color_palette('tab10', 4).as_hex()
palette_b = sns.color_palette('pastel', 4).as_hex()

palette_c = [None]*(len(palette_a)+len(palette_b))
palette_c[::2] = palette_a
palette_c[1::2] = palette_b
palette_c
# Out:
# ['#1f77b4',
#  '#a1c9f4',
#  '#ff7f0e',
#  '#ffb482',
#  '#2ca02c',
#  '#8de5a1',
#  '#d62728',
#  '#ff9f9b']

# %%
model_run_peer_group = ols('Correct_RT_logz ~ C(Peer) * Run * group', data=rt_data_mod,
                          missing='drop').fit()
print(sm.stats.anova_lm(model_run_peer_group, typ=2))
# Out:
#                         sum_sq      df          F        PR(>F)
# C(Peer)               3.124427     2.0   1.582278  2.055925e-01
# Run                  67.323071     3.0  22.729246  1.257709e-14
# group                 0.000030     1.0   0.000031  9.955697e-01
# C(Peer):Run           5.220350     6.0   0.881233  5.075860e-01
# C(Peer):group         1.411479     2.0   0.714804  4.893298e-01
# Run:group             9.615188     3.0   3.246227  2.099120e-02
# C(Peer):Run:group    13.211135     6.0   2.230135  3.751772e-02
# Residual           5907.131424  5983.0        NaN           NaN

# %%
ax = sns.boxplot(rt_data_mod, x='Peer', y='Correct_RT_logz', hue='Run_group', showfliers=False,
                hue_order = ['1_1', '1_2', '2_1', '2_2',
                         '3_1', '3_2', '4_1', '4_2'],
            palette=palette_c)


handler, label = ax.get_legend_handles_labels()
ax.legend(handler, ['Run 1 - TD', 'Run 1 - ASD', 'Run 2 - TD', 'Run 2 - ASD',
                   'Run 3 - TD', 'Run 3 - ASD', 'Run 4 - TD', 'Run 4 - ASD'],
          bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0,
           fontsize=10)

# %% [markdown]
# **Figure note:** Bolder colors = TD, pastel colors = ASD

# %% [markdown]
# ***
# # Reinforcement Learning Modeling

# %%
np.range(-5,5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 np.range(-5,5)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/__init__.py:320, in __getattr__(attr)
#     317     from .testing import Tester
#     318     return Tester
# --> 320 raise AttributeError("module {!r} has no attribute "
#     321                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'range'

# %%
T = 96
K = 2
mu = [0.25, 0.75]
# Out:
#    participant_id group Run        ConditionName  Correct_RT      Peer
# 0         SCN_101     1   2   HighReward_DisPeer    0.735915   DisPeer
# 1         SCN_101     1   2   LowReward_Computer    0.897369  Computer
# 2         SCN_101     1   2   HighReward_SimPeer    1.268269   SimPeer
# 3         SCN_101     1   2  HighReward_Computer    0.775542  Computer
# 4         SCN_101     1   2  HighReward_Computer    1.093963  Computer
# ..            ...   ...  ..                  ...         ...       ...
# 91        SCN_101     1   4    LowReward_DisPeer    1.229602   DisPeer
# 92        SCN_101     1   4   HighReward_SimPeer    0.657721   SimPeer
# 93        SCN_101     1   4  HighReward_Computer    0.673613  Computer
# 94        SCN_101     1   4    LowReward_DisPeer    0.643297   DisPeer
# 95        SCN_101     1   4   LowReward_Computer    0.709759  Computer
#
# [96 rows x 6 columns]
